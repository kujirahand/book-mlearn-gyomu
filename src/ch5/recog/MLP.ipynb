# %%
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
from PIL import Image

plt.figure(figsize=(10, 10))
labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
for i in range(0, 40):
    im = Image.fromarray(X_train[i])
    plt.subplot(5, 8, i + 1)
    plt.title(labels[y_train[i][0]])
    plt.tick_params(labelbottom="off",bottom="off") # x軸をオフ
    plt.tick_params(labelleft="off",left="off") # y軸をオフ
    plt.imshow(im)

plt.show()

# %%
X_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout

num_classes = 10
im_rows = 32
im_cols = 32
im_size = im_rows * im_cols * 3

# データを読み込む --- (*1)
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# データを一次元配列に変換 --- (*2)
X_train = X_train.reshape(-1, im_size).astype('float32') / 255
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# ラベルデータをOne-Hot形式に変換
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# モデルを定義 --- (*3)
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(im_size,)))
model.add(Dense(num_classes, activation='softmax'))

# モデルをコンパイル --- (*4)
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 学習を実行 --- (*5)
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=50,
    verbose=1,
    validation_data=(X_test, y_test))

# モデルを評価 --- (*6)
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])

# 学習の様子をグラフへ描画 --- (*7)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 1.8944 - accuracy: 0.3268 - val_loss: 1.7308 - val_accuracy: 0.3777
# Epoch 2/50
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.7124 - accuracy: 0.3854 - val_loss: 1.6858 - val_accuracy: 0.3917
# Epoch 3/50
# 50000/50000 [==============================] - 14s 283us/step - loss: 1.6453 - accuracy: 0.4134 - val_loss: 1.6168 - val_accuracy: 0.4211
# Epoch 4/50
# 50000/50000 [==============================] - 14s 282us/step - loss: 1.6020 - accuracy: 0.4303 - val_loss: 1.6048 - val_accuracy: 0.4249
# Epoch 5/50
# 50000/50000 [==============================] - 14s 283us/step - loss: 1.5646 - accuracy: 0.4424 - val_loss: 1.5831 - val_accuracy: 0.4312
# Epoch 6/50
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.5430 - accuracy: 0.4498 - val_loss: 1.5627 - val_accuracy: 0.4426
# Epoch 7/50
# 50000/50000 [==============================] - 14s 286us/step - loss: 1.5194 - accuracy: 0.4573 - val_loss: 1.5319 - val_accuracy: 0.4617
# Epoch 8/50
# 50000/50000 [==============================] - 14s 288us/step - loss: 1.5052 - accuracy: 0.4641 - val_loss: 1.5100 - val_accuracy: 0.4664
# Epoch 9/50
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.4898 - accuracy: 0.4690 - val_loss: 1.5349 - val_accuracy: 0.4561
# Epoch 10/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.4785 - accuracy: 0.4710 - val_loss: 1.5193 - val_accuracy: 0.4616
# Epoch 11/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4686 - accuracy: 0.4772 - val_loss: 1.5275 - val_accuracy: 0.4616
# Epoch 12/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4590 - accuracy: 0.4802 - val_loss: 1.5265 - val_accuracy: 0.4562
# Epoch 13/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.4482 - accuracy: 0.4836 - val_loss: 1.5201 - val_accuracy: 0.4605
# Epoch 14/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.4413 - accuracy: 0.4864 - val_loss: 1.5269 - val_accuracy: 0.4577
# Epoch 15/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.4364 - accuracy: 0.4885 - val_loss: 1.5260 - val_accuracy: 0.4589
# Epoch 16/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.4328 - accuracy: 0.4899 - val_loss: 1.5028 - val_accuracy: 0.4660
# Epoch 17/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.4224 - accuracy: 0.4924 - val_loss: 1.5261 - val_accuracy: 0.4631
# Epoch 18/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.4201 - accuracy: 0.4941 - val_loss: 1.5335 - val_accuracy: 0.4587
# Epoch 19/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.4128 - accuracy: 0.4973 - val_loss: 1.5282 - val_accuracy: 0.4613
# Epoch 20/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.4053 - accuracy: 0.5010 - val_loss: 1.4934 - val_accuracy: 0.4688
# Epoch 21/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.3994 - accuracy: 0.5025 - val_loss: 1.5197 - val_accuracy: 0.4658
# Epoch 22/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.3975 - accuracy: 0.5024 - val_loss: 1.4834 - val_accuracy: 0.4752
# Epoch 23/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.3940 - accuracy: 0.5051 - val_loss: 1.4977 - val_accuracy: 0.4843
# Epoch 24/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.3861 - accuracy: 0.5103 - val_loss: 1.4856 - val_accuracy: 0.4737
# Epoch 25/50
# 50000/50000 [==============================] - 15s 302us/step - loss: 1.3816 - accuracy: 0.5085 - val_loss: 1.5098 - val_accuracy: 0.4620
# Epoch 26/50
# 50000/50000 [==============================] - 17s 332us/step - loss: 1.3821 - accuracy: 0.5091 - val_loss: 1.4890 - val_accuracy: 0.4804
# Epoch 27/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.3737 - accuracy: 0.5130 - val_loss: 1.4842 - val_accuracy: 0.4781
# Epoch 28/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.3713 - accuracy: 0.5109 - val_loss: 1.5246 - val_accuracy: 0.4657
# Epoch 29/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.3677 - accuracy: 0.5147 - val_loss: 1.5208 - val_accuracy: 0.4692
# Epoch 30/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.3666 - accuracy: 0.5139 - val_loss: 1.4985 - val_accuracy: 0.4747
# Epoch 31/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.3610 - accuracy: 0.5152 - val_loss: 1.4942 - val_accuracy: 0.4822
# Epoch 32/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.3590 - accuracy: 0.5172 - val_loss: 1.4890 - val_accuracy: 0.4749
# Epoch 33/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.3523 - accuracy: 0.5189 - val_loss: 1.5070 - val_accuracy: 0.4794
# Epoch 34/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.3486 - accuracy: 0.5210 - val_loss: 1.4774 - val_accuracy: 0.4815
# Epoch 35/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.3500 - accuracy: 0.5200 - val_loss: 1.5046 - val_accuracy: 0.4707
# Epoch 36/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.3461 - accuracy: 0.5206 - val_loss: 1.5627 - val_accuracy: 0.4567
# Epoch 37/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.3423 - accuracy: 0.5219 - val_loss: 1.5528 - val_accuracy: 0.4575
# Epoch 38/50
# 50000/50000 [==============================] - 15s 302us/step - loss: 1.3361 - accuracy: 0.5261 - val_loss: 1.5022 - val_accuracy: 0.4819
# Epoch 39/50
# 50000/50000 [==============================] - 15s 304us/step - loss: 1.3417 - accuracy: 0.5230 - val_loss: 1.5119 - val_accuracy: 0.4774
# Epoch 40/50
# 50000/50000 [==============================] - 15s 304us/step - loss: 1.3347 - accuracy: 0.5242 - val_loss: 1.5129 - val_accuracy: 0.4702
# Epoch 41/50
# 50000/50000 [==============================] - 15s 306us/step - loss: 1.3313 - accuracy: 0.5257 - val_loss: 1.5278 - val_accuracy: 0.4722
# Epoch 42/50
# 50000/50000 [==============================] - 15s 306us/step - loss: 1.3274 - accuracy: 0.5258 - val_loss: 1.4972 - val_accuracy: 0.4776
# Epoch 43/50
# 50000/50000 [==============================] - 15s 308us/step - loss: 1.3252 - accuracy: 0.5306 - val_loss: 1.5078 - val_accuracy: 0.4732
# Epoch 44/50
# 50000/50000 [==============================] - 15s 306us/step - loss: 1.3279 - accuracy: 0.5260 - val_loss: 1.5206 - val_accuracy: 0.4718
# Epoch 45/50
# 50000/50000 [==============================] - 15s 309us/step - loss: 1.3236 - accuracy: 0.5285 - val_loss: 1.5359 - val_accuracy: 0.4670
# Epoch 46/50
# 50000/50000 [==============================] - 15s 307us/step - loss: 1.3179 - accuracy: 0.5295 - val_loss: 1.5074 - val_accuracy: 0.4781
# Epoch 47/50
# 50000/50000 [==============================] - 15s 310us/step - loss: 1.3178 - accuracy: 0.5306 - val_loss: 1.5201 - val_accuracy: 0.4706
# Epoch 48/50
# 50000/50000 [==============================] - 15s 308us/step - loss: 1.3119 - accuracy: 0.5331 - val_loss: 1.4811 - val_accuracy: 0.4835
# Epoch 49/50
# 50000/50000 [==============================] - 16s 310us/step - loss: 1.3090 - accuracy: 0.5336 - val_loss: 1.4902 - val_accuracy: 0.4851
# Epoch 50/50
# 50000/50000 [==============================] - 15s 307us/step - loss: 1.3096 - accuracy: 0.5317 - val_loss: 1.4912 - val_accuracy: 0.4816
# 10000/10000 [==============================] - 1s 55us/step
# 正解率= 0.48159998655319214 loss= 1.4912029428482056

# %%
model.save_weights('cifar10-mlp-weight.h5')

# %%
import cv2
import numpy as np
# ラベル情報
labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# モデルデータを読み込み
model.load_weights('cifar10-mlp-weight.h5')

# OpenCVを使って画像を読み込む
im = cv2.imread('test-car.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (32, 32))
plt.imshow(im) # 画像を出力
plt.show()

# MLPで学習した画像データに合わせる
im = im.reshape(im_size).astype('float32') / 255
# 予測する
r = model.predict(np.array([im]), batch_size=32,verbose=1)
res = r[0]
# 結果を表示する
for i, acc in enumerate(res):
    print(labels[i], "=", int(acc * 100))
print("---")
print("予測した結果=", labels[res.argmax()])
# Out:
# 1/1 [==============================] - 0s 11ms/step
# airplane = 4
# automobile = 92
# bird = 0
# cat = 0
# deer = 0
# dog = 0
# frog = 0
# horse = 0
# ship = 0
# truck = 3
# ---
# 予測した結果= automobile

# %%
import numpy as np
print(np.array([1, 0, 9, 3]).argmax()) # 結果→ 2
print(np.array([1, 3, 2, 9]).argmax()) # 結果→ 3
print(np.array([9, 0, 2, 3]).argmax()) # 結果→ 0
# Out:
# 2
# 3
# 0
